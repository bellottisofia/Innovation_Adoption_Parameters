# %% [markdown]
# <a href="https://colab.research.google.com/github/bellottisofia/Innovation_Adoption_Parameters/blob/main/similarity_matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.spatial.distance import pdist, squareform
from sklearn.impute import SimpleImputer

# %%
opinion_germany = pd.read_csv('/content/matrix_Germany_year (3).csv')

# %%
opinion_germany.head()
# Out:
#                   popolazione     Q11_1     Q11_2     Q11_3     Q11_4  \
# 0   18 t/m 24_less than 4.999  0.448276  0.206897  0.206897  0.517241
# 1       18 t/m 24_5.000-9.999  0.360000  0.280000  0.160000  0.520000
# 2     18 t/m 24_10.000-19.999  0.363636  0.227273  0.159091  0.522727
# 3     18 t/m 24_20.000-29.999  0.550000  0.300000  0.200000  0.400000
# 4  18 t/m 24_more than 30.000  0.285714  0.238095  0.619048  0.476190
#
#       Q11_5     Q11_6     Q11_7     Q11_8     Q11_9  ...    Q18_16    Q18_17  \
# 0  0.206897  0.000000  0.344828  0.172414  0.034483  ...  0.387931  0.508621
# 1  0.160000  0.080000  0.320000  0.320000  0.160000  ...  0.370000  0.420000
# 2  0.340909  0.113636  0.318182  0.431818  0.113636  ...  0.380682  0.437500
# 3  0.300000  0.150000  0.250000  0.350000  0.050000  ...  0.287500  0.437500
# 4  0.238095  0.190476  0.476190  0.428571  0.285714  ...  0.452381  0.500000
#
#      Q18_18    Q18_19    Q18_20    Q18_21    Q18_22    Q18_23       Q20  \
# 0  0.293103  0.474138  0.456897  0.431034  0.482759  0.405172  0.413793
# 1  0.290000  0.420000  0.350000  0.360000  0.370000  0.340000  0.320000
# 2  0.357955  0.454545  0.346591  0.437500  0.375000  0.346591  0.409091
# 3  0.312500  0.487500  0.400000  0.437500  0.400000  0.425000  0.387500
# 4  0.321429  0.416667  0.392857  0.392857  0.416667  0.464286  0.357143
#
#         Q21
# 0  0.448276
# 1  0.450000
# 2  0.392045
# 3  0.412500
# 4  0.428571
#
# [5 rows x 69 columns]

# %%
popolazioni = opinion_germany['popolazione'].values
opinioni = opinion_germany.drop(columns=['popolazione']).values


# 4. distance matrix
distanze = squareform(pdist(opinioni, metric='euclidean'))

# 5. sigma
sigma_media_germany = np.mean(distanze[np.triu_indices_from(distanze, k=1)])
sigma_mediana_germany = np.median(distanze[np.triu_indices_from(distanze, k=1)])

print("Mean Sigma:", sigma_media_germany)
print("Median Sigma:", sigma_mediana_germany)
# 3. construction of the similarity matrix W using Gaussian Kernel

W_germany = np.exp(-distanze**2 / (2 * sigma_mediana_germany**2))
# Out:
# Mean Sigma: 0.8333114680258732
# Median Sigma: 0.8165305129265699

# %% [markdown]
# We normalize each similarity matrix by rows, in order to obtain stochastic matrices.

# %%
row_sums = W_germany.sum(axis=1, keepdims=True)
W_germany = W_germany / row_sums

# %%
similarity_matrix_germany = pd.DataFrame(W_germany, index=popolazioni, columns=popolazioni)
similarity_matrix_germany.to_csv("similarity_germany_median.csv", index=True)
